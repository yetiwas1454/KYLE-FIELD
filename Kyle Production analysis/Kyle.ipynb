# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
a=pd.read_csv("Kyle master merged data csv format.csv")

# %% [markdown]
# 29/02c -13a

# %%
Z_13=a[a["Well No."]=='29/02c - 13a']
Z_13

Z_13['Date'] = pd.to_datetime(Z_13['Date'], format='%Y-%m-%d')
fig = plt.figure(figsize=(10, 5))
plt.plot(Z_13 ["Date"], Z_13 ['Oil (m3)'], color="blue")
plt.xlabel("Year")
plt.ylabel("Oil Production (m3)")
plt.title('Oil Production Well-29/02C-13a')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()


fig=plt.figure(figsize=(10,5))
plt.plot(Z_13 ["Date"],Z_13 ['Oil (m3)'],color="blue")
plt.xlabel("Year") 
plt.ylabel("Oil Production(m3)")
plt.title('Oil Production Well-29/02C-13a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(Z_13 ["Date"],Z_13 ['Gas (m3)'],color="red")
plt.xlabel("Year")
plt.ylabel("Gas Production(m3)")
plt.title('Gas Production Well-29/02C-13a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(Z_13 ["Date"],Z_13 ['Produced Water (m3)'],color="green")
plt.xlabel("Year")
plt.ylabel("Water Production(m3)")
plt.title('Water Production Well-29/02C-13a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




fig=plt.figure(figsize=(10,5))
plt.plot(Z_13 ["Date"],Z_13 ['Av. DHP (bar) edited'],color="green")
plt.xlabel("Year")
plt.ylabel("Av. DHP (bar)")
plt.title('Av. DHP (bar) Well-29/02C-13a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()



# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_13 ["Date"], Z_13 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_13 ["Date"], Z_13 ["Produced Water (m3)"], color="Blue")
ax2.set_ylabel("Water Production(m3)")

# Set title
plt.title('Oil production vs Water Production')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_13 ["Date"], Z_13 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_13 ["Date"], Z_13 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_13 ["Date"], Z_13 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_13 ["Date"], Z_13 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_13 ["Date"], Z_13 ["Platform Choke %"], color="brown")
ax1.set_xlabel("Months")
ax1.set_ylabel("Choke size(%)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_13 ["Date"], Z_13 ["Oil (m3)"], color="green")
ax2.set_ylabel("Oil production(m3)")

# Set title
plt.title('Oil production vs Choke Size')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_13 ["Date"], Z_13 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_13 ["Date"], Z_13 ["Av. DHP (bar)"], color="yellow")
ax2.set_ylabel("Av. DHP (bar) edited")

# Set title
plt.title('Oil production vs BHP')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()

# %% [markdown]
# 29/02c - 12z

# %%
z_12=a[a["Well No."]=='29/02c - 12z']
z_12

z_12['Date'] = pd.to_datetime(z_12['Date'], format='%Y-%m-%d')
fig = plt.figure(figsize=(10, 5))
plt.plot(z_12 ["Date"], z_12 ['Oil (m3)'], color="blue")
plt.xlabel("Year")
plt.ylabel("Oil Production (m3)")
plt.title('Oil Production Well-29/02C-12z')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()


fig=plt.figure(figsize=(10,5))
plt.plot(z_12 ["Date"],z_12 ['Oil (m3)'],color="blue")
plt.xlabel("Year") 
plt.ylabel("Oil Production(m3)")
plt.title('Oil Production Well-29/02C-12z')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(z_12 ["Date"],z_12 ['Gas (m3)'],color="red")
plt.xlabel("Year")
plt.ylabel("Gas Production(m3)")
plt.title('Gas Production Well-29/02C-12z')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(z_12 ["Date"],z_12 ['Produced Water (m3)'],color="green")
plt.xlabel("Year")
plt.ylabel("Water Production(m3)")
plt.title('Water Production Well-29/02C-12z')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




fig=plt.figure(figsize=(10,5))
plt.plot(z_12 ["Date"],z_12 ['Av. DHP (bar) edited'],color="green")
plt.xlabel("Year")
plt.ylabel("Av. DHP (bar)")
plt.title('Av. DHP (bar) Well-29/02C-12z')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()



# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(z_12 ["Date"], z_12 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(z_12 ["Date"], z_12 ["Produced Water (m3)"], color="Blue")
ax2.set_ylabel("Water Production(m3)")

# Set title
plt.title('Oil production vs Water Production')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(z_12 ["Date"], z_12 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(z_12 ["Date"], z_12 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(z_12 ["Date"], z_12 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(z_12 ["Date"], z_12 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(z_12 ["Date"], z_12 ["Platform Choke %"], color="brown")
ax1.set_xlabel("Months")
ax1.set_ylabel("Choke size(%)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(z_12 ["Date"], z_12 ["Oil (m3)"], color="green")
ax2.set_ylabel("Oil production(m3)")

# Set title
plt.title('Oil production vs Choke Size')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(z_12 ["Date"], z_12 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(z_12 ["Date"], z_12 ["Av. DHP (bar)"], color="yellow")
ax2.set_ylabel("Av. DHP (bar) edited")

# Set title
plt.title('Oil production vs BHP')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_4104\352890876.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z_12['Date'] = pd.to_datetime(z_12['Date'], format='%Y-%m-%d')

# %% [markdown]
# 29/02c - 14A

# %%
Z_14=a[a["Well No."]=='29/02c - 14A']
Z_14

Z_14['Date'] = pd.to_datetime(Z_14['Date'], format='%Y-%m-%d')
fig = plt.figure(figsize=(10, 5))
plt.plot(Z_14 ["Date"], Z_14 ['Oil (m3)'], color="blue")
plt.xlabel("Year")
plt.ylabel("Oil Production (m3)")
plt.title('Oil Production Well-29/02C-14A')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()


fig=plt.figure(figsize=(10,5))
plt.plot(Z_14 ["Date"],Z_14 ['Oil (m3)'],color="blue")
plt.xlabel("Year") 
plt.ylabel("Oil Production(m3)")
plt.title('Oil Production Well-29/02C-14A')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(Z_14 ["Date"],Z_14 ['Gas (m3)'],color="red")
plt.xlabel("Year")
plt.ylabel("Gas Production(m3)")
plt.title('Gas Production Well-29/02C-14A')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(Z_14 ["Date"],Z_14 ['Produced Water (m3)'],color="green")
plt.xlabel("Year")
plt.ylabel("Water Production(m3)")
plt.title('Water Production Well-29/02C-14A')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




fig=plt.figure(figsize=(10,5))
plt.plot(Z_14 ["Date"],Z_14 ['Av. DHP (bar) edited'],color="green")
plt.xlabel("Year")
plt.ylabel("Av. DHP (bar)")
plt.title('Av. DHP (bar) Well-29/02C-14A')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()



# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_14 ["Date"], Z_14 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_14 ["Date"], Z_14 ["Produced Water (m3)"], color="Blue")
ax2.set_ylabel("Water Production(m3)")

# Set title
plt.title('Oil production vs Water Production')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_14 ["Date"], Z_14 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_14 ["Date"], Z_14 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_14 ["Date"], Z_14 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_14 ["Date"], Z_14 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_14 ["Date"], Z_14 ["Platform Choke %"], color="brown")
ax1.set_xlabel("Months")
ax1.set_ylabel("Choke size(%)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_14 ["Date"], Z_14 ["Oil (m3)"], color="green")
ax2.set_ylabel("Oil production(m3)")

# Set title
plt.title('Oil production vs Choke Size')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_14 ["Date"], Z_14 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_14 ["Date"], Z_14 ["Av. DHP (bar)"], color="yellow")
ax2.set_ylabel("Av. DHP (bar) edited")

# Set title
plt.title('Oil production vs BHP')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_4104\3342392936.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z_14['Date'] = pd.to_datetime(Z_14['Date'], format='%Y-%m-%d')

# %% [markdown]
# 29/02C - 15a

# %%
Z_15=a[a["Well No."]=='29/02C - 15a']
Z_15
Z_15['Date'] = pd.to_datetime(Z_15['Date'], format='%Y-%m-%d')
fig = plt.figure(figsize=(10, 5))
plt.plot(Z_15 ["Date"], Z_15 ['Oil (m3)'], color="blue")
plt.xlabel("Year")
plt.ylabel("Oil Production (m3)")
plt.title('Oil Production Well-29/02C-15a')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()


fig=plt.figure(figsize=(10,5))
plt.plot(Z_15 ["Date"],Z_15 ['Oil (m3)'],color="blue")
plt.xlabel("Year") 
plt.ylabel("Oil Production(m3)")
plt.title('Oil Production Well-29/02C-15a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(Z_15 ["Date"],Z_15 ['Gas (m3)'],color="red")
plt.xlabel("Year")
plt.ylabel("Gas Production(m3)")
plt.title('Gas Production Well-29/02C-15a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()





fig=plt.figure(figsize=(10,5))
plt.plot(Z_15 ["Date"],Z_15 ['Produced Water (m3)'],color="green")
plt.xlabel("Year")
plt.ylabel("Water Production(m3)")
plt.title('Water Production Well-29/02C-15a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




fig=plt.figure(figsize=(10,5))
plt.plot(Z_15 ["Date"],Z_15 ['Av. DHP (bar) edited'],color="green")
plt.xlabel("Year")
plt.ylabel("Av. DHP (bar)")
plt.title('Av. DHP (bar) Well-29/02C-15a')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()



# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_15 ["Date"], Z_15 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_15 ["Date"], Z_15 ["Produced Water (m3)"], color="Blue")
ax2.set_ylabel("Water Production(m3)")

# Set title
plt.title('Oil production vs Water Production')
# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_15 ["Date"], Z_15 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_15 ["Date"], Z_15 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()




# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_15 ["Date"], Z_15 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_15 ["Date"], Z_15 ["Gas (m3)"], color="red")
ax2.set_ylabel("Gas Production(m3)")

# Set title
plt.title('Oil production vs Gas Production')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_15 ["Date"], Z_15 ["Platform Choke %"], color="brown")
ax1.set_xlabel("Months")
ax1.set_ylabel("Choke size(%)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_15 ["Date"], Z_15 ["Oil (m3)"], color="green")
ax2.set_ylabel("Oil production(m3)")

# Set title
plt.title('Oil production vs Choke Size')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()






# Increase the size of the figure
fig = plt.figure(figsize=(15, 8))  # Adjust width and height as needed1

# Create the first subplot
ax1 = fig.add_subplot(111)
ax1.plot(Z_15 ["Date"], Z_15 ["Oil (m3)"],color="green")
ax1.set_xlabel("Months")
ax1.set_ylabel("Oil production(m3)")

# Create the second subplot sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(Z_15 ["Date"], Z_15 ["Av. DHP (bar)"], color="yellow")
ax2.set_ylabel("Av. DHP (bar) edited")

# Set title
plt.title('Oil production vs BHP')

# Formatting the x-axis to show only the year as a label
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

# Rotate and align the x labels for better readability
plt.gcf().autofmt_xdate()

plt.show()
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_4104\2716436111.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z_15['Date'] = pd.to_datetime(Z_15['Date'], format='%Y-%m-%d')

# %% [markdown]
# 29/02a - B5X
